# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
root = "/media/digits2/9baf4857-aa15-462d-b5db-022aa5cc3dc5/MicrosurgicalTooltracking/data/EndoVis/labelled_train/"

# %%
img = cv2.imread(root + "img_000065_raw_train1.jpg")[:, :, (2, 1, 0)]

# %%
plt.imshow(img)
plt.show()

# %%
target = np.load("/media/digits2/9baf4857-aa15-462d-b5db-022aa5cc3dc5/MicrosurgicalTooltracking/data/EndoVis/training_labels/img_000065_raw_train1.npy")

# %%
plt.imshow(target[:, :, 0], cmap="gray")
plt.show()

# %%
_, _, _, m_loc = cv2.minMaxLoc(target[:, :, 0])
print(m_loc)
# Out:
# (353, 335)

# %%
target[m_loc[1]-40:m_loc[1]+40, m_loc[0]-40:m_loc[0]+40, 0] = 0
plt.imshow(target[:, :, 0], cmap="gray")
plt.show()

# %%
_, _, _, m_loc = cv2.minMaxLoc(target[:, :, 0])
print(m_loc)
# Out:
# (303, 285)
